# %%
from databroker import catalog

# %%
db = catalog["xpd"]

# %%
db
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/conda_envs/nsls2-analysis-2021-1.0-xpdacq/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     916             method = get_real_method(obj, self.print_method)
#     917             if method is not None:
# --> 918                 method()
#     919                 return True
#     920
#
# /opt/conda_envs/nsls2-analysis-2021-1.0-xpdacq/lib/python3.7/site-packages/intake/source/base.py in _ipython_display_(self)
#     166         from IPython.display import display
#     167         data = self._yaml()['sources']
# --> 168         contents = dump(data, default_flow_style=False)
#     169         display({
#     170             'application/json': contents,
#
# /opt/conda_envs/nsls2-analysis-2021-1.0-xpdacq/lib/python3.7/site-packages/yaml/__init__.py in dump(data, stream, Dumper, **kwds)
# ...
