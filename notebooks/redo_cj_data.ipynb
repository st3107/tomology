# %% [markdown]
# # Try to repeat what CJ did

# %%
from databroker import catalog

db = catalog["pdf"]
lightRun = db["8f51c070-a53a-4a25-9178-0e69a81dd834"]
darkRun = db[lightRun.metadata["start"]["sc_dk_field_uid"]]

lightRun.primary.read()
# Out:
# --------------------------------------------------
# KeyError         Traceback (most recent call last)
# ~/envs/analysis-2021-stao/lib/python3.8/site-packages/event_model/__init__.py in fill_event(self, doc, include, exclude, inplace)
#     929             try:
# --> 930                 datum_doc = self._datum_cache[datum_id]
#     931             except KeyError as err:
#
# KeyError: '04cc4107-d79d-40de-9eb4-63c1c6dd11c9/0'
#
# The above exception was the direct cause of the following exception:
#
# UnresolvableForeignKeyErrorTraceback (most recent call last)
# ~/envs/analysis-2021-stao/lib/python3.8/site-packages/bluesky_live/conversion.py in _fill(filler, event, lookup_resource_for_datum, get_resource, get_datum_pages, last_datum_id)
#     291     try:
# --> 292         _, filled_event = filler("event", event)
#     293         return filled_event
#
# ~/envs/analysis-2021-stao/lib/python3.8/site-packages/event_model/__init__.py in __call__(self, name, doc, validate)
# ...
